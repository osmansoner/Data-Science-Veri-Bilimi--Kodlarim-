# %%
import pandas as pd

# %%
d = pd.read_csv("https://data.cdc.gov/api/views/bi63-dtpu/rows.csv")

# %%
d
# Out:
#        Year                                     113 Cause Name  \
# 0      2012  Nephritis, nephrotic syndrome and nephrosis (N...
# 1      2016  Nephritis, nephrotic syndrome and nephrosis (N...
# 2      2013  Nephritis, nephrotic syndrome and nephrosis (N...
# 3      2000  Intentional self-harm (suicide) (*U03,X60-X84,...
# 4      2014  Nephritis, nephrotic syndrome and nephrosis (N...
# 5      2009  Intentional self-harm (suicide) (*U03,X60-X84,...
# 6      2011  Nephritis, nephrotic syndrome and nephrosis (N...
# 7      2015  Nephritis, nephrotic syndrome and nephrosis (N...
# 8      2014  Nephritis, nephrotic syndrome and nephrosis (N...
# 9      2013  Nephritis, nephrotic syndrome and nephrosis (N...
# 10     2015  Intentional self-harm (suicide) (*U03,X60-X84,...
# 11     2001  Nephritis, nephrotic syndrome and nephrosis (N...
# 12     1999  Intentional self-harm (suicide) (*U03,X60-X84,...
# 13     1999  Nephritis, nephrotic syndrome and nephrosis (N...
# ...

# %%
d["State"].tolist()
# Out:
# ['Vermont',
#  'Vermont',
#  'Vermont',
#  'District of Columbia',
#  'Arizona',
#  'District of Columbia',
#  'South Dakota',
#  'Vermont',
#  'Vermont',
#  'Arizona',
#  'District of Columbia',
#  'Washington',
#  'District of Columbia',
#  'Washington',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'Washington',
#  'Vermont',
#  'Vermont',
#  'Washington',
#  'Washington',
#  'District of Columbia',
#  'Arizona',
#  'District of Columbia',
#  'Arizona',
#  'South Dakota',
#  'District of Columbia',
#  'Arizona',
#  'Arizona',
#  'District of Columbia',
#  'District of Columbia',
#  'Iowa',
#  'South Dakota',
#  'South Dakota',
#  'Washington',
#  'Washington',
#  'New York',
#  'New York',
#  'Iowa',
#  'District of Columbia',
#  'Massachusetts',
#  'New York',
#  'New York',
#  'Washington',
#  'District of Columbia',
#  'New Jersey',
#  'California',
#  'North Dakota',
#  'Washington',
#  'New Jersey',
#  'North Dakota',
#  'New Jersey',
# ...

# %%
state = d["State"].to_frame()
state
# Out:
#                       State
# 0                   Vermont
# 1                   Vermont
# 2                   Vermont
# 3      District of Columbia
# 4                   Arizona
# 5      District of Columbia
# 6              South Dakota
# 7                   Vermont
# 8                   Vermont
# 9                   Arizona
# 10     District of Columbia
# 11               Washington
# 12     District of Columbia
# 13               Washington
# 14     District of Columbia
# 15     District of Columbia
# 16     District of Columbia
# 17               Washington
# 18                  Vermont
# 19                  Vermont
# 20               Washington
# 21               Washington
# 22     District of Columbia
# 23                  Arizona
# 24     District of Columbia
# 25                  Arizona
# 26             South Dakota
# 27     District of Columbia
# 28                  Arizona
# 29                  Arizona
# ...                     ...
# 10266         West Virginia
# ...

# %%
state.to_csv("state.csv",index=False)

# %%
pd.read_csv("state.csv")
# Out:
#                       State
# 0                   Vermont
# 1                   Vermont
# 2                   Vermont
# 3      District of Columbia
# 4                   Arizona
# 5      District of Columbia
# 6              South Dakota
# 7                   Vermont
# 8                   Vermont
# 9                   Arizona
# 10     District of Columbia
# 11               Washington
# 12     District of Columbia
# 13               Washington
# 14     District of Columbia
# 15     District of Columbia
# 16     District of Columbia
# 17               Washington
# 18                  Vermont
# 19                  Vermont
# 20               Washington
# 21               Washington
# 22     District of Columbia
# 23                  Arizona
# 24     District of Columbia
# 25                  Arizona
# 26             South Dakota
# 27     District of Columbia
# 28                  Arizona
# 29                  Arizona
# ...                     ...
# 10266         West Virginia
# ...

# %%
c = pd.read_excel("excel.xlsx",sheet_name=["2006","2010"])

# %%
c["2006"]
# Out:
#           Futbolcu  Gol
# 0   Miroslav Klose    5
# 1   Lucas Podolski    4
# 2      David Villa    3
# 3   Maxi Rodriguez    3
# 4    Thierry Henry    3
# 5  Zinedine Zidane    3
# 6    Hernan Crespo    3
# 7  Fernando Torres    3
# 8          Ronaldo    3
# 9         Adriano     2

# %%
c["2010"]
# Out:
#           Futbolcu  Gol
# 0      David Villa    5
# 1  Wesley Sneijder    5
# 2     Diego Forlan    5
# 3    Thomas Müller    5
# 4   Miroslav Klose    4
# 5    Robert Vittek    4
# 6        G.Higuain    4
# 7     Asamoah Gyan    3
# 8   Landon Donovan    3
# 9      Luis Suares    3

# %%
c
# Out:
# OrderedDict([('2006',           Futbolcu  Gol
#               0   Miroslav Klose    5
#               1   Lucas Podolski    4
#               2      David Villa    3
#               3   Maxi Rodriguez    3
#               4    Thierry Henry    3
#               5  Zinedine Zidane    3
#               6    Hernan Crespo    3
#               7  Fernando Torres    3
#               8          Ronaldo    3
#               9         Adriano     2), ('2010',           Futbolcu  Gol
#               0      David Villa    5
#               1  Wesley Sneijder    5
#               2     Diego Forlan    5
#               3    Thomas Müller    5
#               4   Miroslav Klose    4
#               5    Robert Vittek    4
#               6        G.Higuain    4
#               7     Asamoah Gyan    3
#               8   Landon Donovan    3
#               9      Luis Suares    3)])

# %%
dönüş = pd.read_csv("2014 wc.csv")

# %%
dönüş.to_excel("2014.xlsx",sheet_name="2014")

# %%
netten = pd.read_html("https://ipfs.io/ipfs/QmXoypizjW3WknFiJnKLwHCnL72vedxjQkDDP1mXWo6uco/wiki/List_of_banks_in_Turkey.html")

# %%
netten[0] #çok karışık olduğu için ilk elemanı okuduk aşağıda ful kaynaktan alınan bilgi var.
# Out:
#                                     Bank  Foundation  \
# 0                         Ziraat Bankası        1863
# 1                     Türkiye İş Bankası        1924
# 2                           Garanti Bank        1946
# 3                                 Akbank        1948
# 4                  Yapı ve Kredi Bankası        1944
# 5                           Halk Bankası        1938
# 6                              VakıfBank        1954
# 7                             Finansbank        1987
# 8                   Türk Ekonomi Bankası        1927
# 9                              Denizbank        1997
# 10                             HSBC Bank        1990
# 11                              ING Bank        1984
# 12                         Türk Eximbank        1987
# 13                              Odeabank        2012
# 14                             Şekerbank        1953
# 15                         İller Bankası        1933
# 16        Türkiye Sınai Kalkınma Bankası        1950
# ...

# %%
netten
# Out:
# [                                    Bank  Foundation  \
#  0                         Ziraat Bankası        1863
#  1                     Türkiye İş Bankası        1924
#  2                           Garanti Bank        1946
#  3                                 Akbank        1948
#  4                  Yapı ve Kredi Bankası        1944
#  5                           Halk Bankası        1938
#  6                              VakıfBank        1954
#  7                             Finansbank        1987
#  8                   Türk Ekonomi Bankası        1927
#  9                              Denizbank        1997
#  10                             HSBC Bank        1990
#  11                              ING Bank        1984
#  12                         Türk Eximbank        1987
#  13                              Odeabank        2012
#  14                             Şekerbank        1953
#  15                         İller Bankası        1933
# ...
