# %%
import pandas as pd

# %%
df = pd.read_csv("millitakım.csv",index_col="İsim")

# %%
df
# Out:
#                     Numara      Görev Doğum Tarihi  Yaş         Takım     Boy  \
# İsim
# Harun Tekin              1     kaleci    17-6-1989   29         Bursa  1,87 m
# Sinan Bolat             23     kaleci     3-9-1988   29      Royal FC  1,88 m
# Serkan Kirintili        12     kaleci    15-2-1985   33         Konya  1,86 m
# Caglar Söyüncü           4     stoper    23-5-1996   22   Sc Freiburg  1,87 m
# Kaan Ayhan              22     stoper   10-11-1994   23    Düsseldorf  1,85 m
# Ertugrul Ersoy          24     stoper    13-2-1997   21         Bursa  1,87 m
# Hasan Ali Kaldirim       3    sol bek    9-12-1989   28    Fenerbahçe  1,83 m
# Ömer Bayram              6    sol bek    27-7-1991   26       Akhisar  1,75 m
# Sener Özbayrakli         2    sağ bek    23-1-1990   28    Fenerbahçe  1,71 m
# Zeki Celik              13    sağ bek    17-2-1997   21      İstanbul  1,80 m
# Okay Yokuslu             5   önlibero     9-3-1994   24       Trabzon  1,91 m
# ...

# %%
df.iloc[4,0] = 100 # 4.satır 0. sütun

# %%
df
# Out:
#                     Numara      Görev Doğum Tarihi  Yaş         Takım     Boy  \
# İsim
# Harun Tekin              1     kaleci    17-6-1989   29         Bursa  1,87 m
# Sinan Bolat             23     kaleci     3-9-1988   29      Royal FC  1,88 m
# Serkan Kirintili        12     kaleci    15-2-1985   33         Konya  1,86 m
# Caglar Söyüncü           4     stoper    23-5-1996   22   Sc Freiburg  1,87 m
# Kaan Ayhan             100     stoper   10-11-1994   23    Düsseldorf  1,85 m
# Ertugrul Ersoy          24     stoper    13-2-1997   21         Bursa  1,87 m
# Hasan Ali Kaldirim       3    sol bek    9-12-1989   28    Fenerbahçe  1,83 m
# Ömer Bayram              6    sol bek    27-7-1991   26       Akhisar  1,75 m
# Sener Özbayrakli         2    sağ bek    23-1-1990   28    Fenerbahçe  1,71 m
# Zeki Celik              13    sağ bek    17-2-1997   21      İstanbul  1,80 m
# Okay Yokuslu             5   önlibero     9-3-1994   24       Trabzon  1,91 m
# ...

# %%
df.iloc[[4,5,6],0] = [3000,4000,5000]

# %%
df
# Out:
#                     Numara      Görev Doğum Tarihi  Yaş         Takım     Boy  \
# İsim
# Harun Tekin              1     kaleci    17-6-1989   29         Bursa  1,87 m
# Sinan Bolat             23     kaleci     3-9-1988   29      Royal FC  1,88 m
# Serkan Kirintili        12     kaleci    15-2-1985   33         Konya  1,86 m
# Caglar Söyüncü           4     stoper    23-5-1996   22   Sc Freiburg  1,87 m
# Kaan Ayhan            3000     stoper   10-11-1994   23    Düsseldorf  1,85 m
# Ertugrul Ersoy        4000     stoper    13-2-1997   21         Bursa  1,87 m
# Hasan Ali Kaldirim    5000    sol bek    9-12-1989   28    Fenerbahçe  1,83 m
# Ömer Bayram              6    sol bek    27-7-1991   26       Akhisar  1,75 m
# Sener Özbayrakli         2    sağ bek    23-1-1990   28    Fenerbahçe  1,71 m
# Zeki Celik              13    sağ bek    17-2-1997   21      İstanbul  1,80 m
# Okay Yokuslu             5   önlibero     9-3-1994   24       Trabzon  1,91 m
# ...

# %%
f = df["Takım"] == "Fenerbahçe"

# %%
df.loc[f,"Takım"] = "FENERBAHÇE"

# %%
df
# Out:
#                     Numara      Görev Doğum Tarihi  Yaş         Takım     Boy  \
# İsim
# Harun Tekin              1     kaleci    17-6-1989   29         Bursa  1,87 m
# Sinan Bolat             23     kaleci     3-9-1988   29      Royal FC  1,88 m
# Serkan Kirintili        12     kaleci    15-2-1985   33         Konya  1,86 m
# Caglar Söyüncü           4     stoper    23-5-1996   22   Sc Freiburg  1,87 m
# Kaan Ayhan            3000     stoper   10-11-1994   23    Düsseldorf  1,85 m
# Ertugrul Ersoy        4000     stoper    13-2-1997   21         Bursa  1,87 m
# Hasan Ali Kaldirim    5000    sol bek    9-12-1989   28    FENERBAHÇE  1,83 m
# Ömer Bayram              6    sol bek    27-7-1991   26       Akhisar  1,75 m
# Sener Özbayrakli         2    sağ bek    23-1-1990   28    FENERBAHÇE  1,71 m
# Zeki Celik              13    sağ bek    17-2-1997   21      İstanbul  1,80 m
# Okay Yokuslu             5   önlibero     9-3-1994   24       Trabzon  1,91 m
# ...

# %%
df.rename(columns={"Görev":"Mevki","Maç":"Match"})
# Out:
#                     Numara      Mevki Doğum Tarihi  Yaş         Takım     Boy  \
# İsim
# Harun Tekin              1     kaleci    17-6-1989   29         Bursa  1,87 m
# Sinan Bolat             23     kaleci     3-9-1988   29      Royal FC  1,88 m
# Serkan Kirintili        12     kaleci    15-2-1985   33         Konya  1,86 m
# Caglar Söyüncü           4     stoper    23-5-1996   22   Sc Freiburg  1,87 m
# Kaan Ayhan            3000     stoper   10-11-1994   23    Düsseldorf  1,85 m
# Ertugrul Ersoy        4000     stoper    13-2-1997   21         Bursa  1,87 m
# Hasan Ali Kaldirim    5000    sol bek    9-12-1989   28    FENERBAHÇE  1,83 m
# Ömer Bayram              6    sol bek    27-7-1991   26       Akhisar  1,75 m
# Sener Özbayrakli         2    sağ bek    23-1-1990   28    FENERBAHÇE  1,71 m
# Zeki Celik              13    sağ bek    17-2-1997   21      İstanbul  1,80 m
# Okay Yokuslu             5   önlibero     9-3-1994   24       Trabzon  1,91 m
# ...

# %%
df.rename(index={"Cengiz Ünder":"CENGİZ ÜNDER"})
# Out:
#                     Numara      Görev Doğum Tarihi  Yaş         Takım     Boy  \
# İsim
# Harun Tekin              1     kaleci    17-6-1989   29         Bursa  1,87 m
# Sinan Bolat             23     kaleci     3-9-1988   29      Royal FC  1,88 m
# Serkan Kirintili        12     kaleci    15-2-1985   33         Konya  1,86 m
# Caglar Söyüncü           4     stoper    23-5-1996   22   Sc Freiburg  1,87 m
# Kaan Ayhan            3000     stoper   10-11-1994   23    Düsseldorf  1,85 m
# Ertugrul Ersoy        4000     stoper    13-2-1997   21         Bursa  1,87 m
# Hasan Ali Kaldirim    5000    sol bek    9-12-1989   28    FENERBAHÇE  1,83 m
# Ömer Bayram              6    sol bek    27-7-1991   26       Akhisar  1,75 m
# Sener Özbayrakli         2    sağ bek    23-1-1990   28    FENERBAHÇE  1,71 m
# Zeki Celik              13    sağ bek    17-2-1997   21      İstanbul  1,80 m
# Okay Yokuslu             5   önlibero     9-3-1994   24       Trabzon  1,91 m
# ...

# %%
df.drop(labels=["Gol","Boy"],axis=1) # boy ve gol kaldırıldı
# Out:
#                     Numara      Görev Doğum Tarihi  Yaş         Takım  \
# İsim
# Harun Tekin              1     kaleci    17-6-1989   29         Bursa
# Sinan Bolat             23     kaleci     3-9-1988   29      Royal FC
# Serkan Kirintili        12     kaleci    15-2-1985   33         Konya
# Caglar Söyüncü           4     stoper    23-5-1996   22   Sc Freiburg
# Kaan Ayhan            3000     stoper   10-11-1994   23    Düsseldorf
# Ertugrul Ersoy        4000     stoper    13-2-1997   21         Bursa
# Hasan Ali Kaldirim    5000    sol bek    9-12-1989   28    FENERBAHÇE
# Ömer Bayram              6    sol bek    27-7-1991   26       Akhisar
# Sener Özbayrakli         2    sağ bek    23-1-1990   28    FENERBAHÇE
# Zeki Celik              13    sağ bek    17-2-1997   21      İstanbul
# Okay Yokuslu             5   önlibero     9-3-1994   24       Trabzon
# Mehmet Topal            15   önlibero     3-3-1986   32    FENERBAHÇE
# ...

# %%
df.pop("Yaş") # yaş kaldırıldı
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Yaş'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-95b6e19cc1c5> in <module>
# ----> 1 df.pop("Yaş") # yaş kaldırıldı
#
# ...

# %%
df
# Out:
#                     Numara      Görev Doğum Tarihi         Takım     Boy  \
# İsim
# Harun Tekin              1     kaleci    17-6-1989         Bursa  1,87 m
# Sinan Bolat             23     kaleci     3-9-1988      Royal FC  1,88 m
# Serkan Kirintili        12     kaleci    15-2-1985         Konya  1,86 m
# Caglar Söyüncü           4     stoper    23-5-1996   Sc Freiburg  1,87 m
# Kaan Ayhan            3000     stoper   10-11-1994    Düsseldorf  1,85 m
# Ertugrul Ersoy        4000     stoper    13-2-1997         Bursa  1,87 m
# Hasan Ali Kaldirim    5000    sol bek    9-12-1989    FENERBAHÇE  1,83 m
# Ömer Bayram              6    sol bek    27-7-1991       Akhisar  1,75 m
# Sener Özbayrakli         2    sağ bek    23-1-1990    FENERBAHÇE  1,71 m
# Zeki Celik              13    sağ bek    17-2-1997      İstanbul  1,80 m
# Okay Yokuslu             5   önlibero     9-3-1994       Trabzon  1,91 m
# Mehmet Topal            15   önlibero     3-3-1986    FENERBAHÇE  1,87 m
# ...
