# %%
import pandas as pd

# %%
veri = pd.read_csv("FL_insurance_sample.csv",squeeze=True)

# %%
veri
# Out:
#        policyID statecode           county  eq_site_limit  hu_site_limit  \
# 0        119736        FL      CLAY COUNTY       498960.0      498960.00
# 1        448094        FL      CLAY COUNTY      1322376.3     1322376.30
# 2        206893        FL      CLAY COUNTY       190724.4      190724.40
# 3        333743        FL      CLAY COUNTY            0.0       79520.76
# 4        172534        FL      CLAY COUNTY            0.0      254281.50
# 5        785275        FL      CLAY COUNTY            0.0      515035.62
# 6        995932        FL      CLAY COUNTY            0.0    19260000.00
# 7        223488        FL      CLAY COUNTY       328500.0      328500.00
# 8        433512        FL      CLAY COUNTY       315000.0      315000.00
# 9        142071        FL      CLAY COUNTY       705600.0      705600.00
# 10       253816        FL      CLAY COUNTY       831498.3      831498.30
# 11       894922        FL      CLAY COUNTY            0.0       24059.09
# ...

# %%
veri[1] #seri csv dosyası olmalı.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-edecc1112bf0> in <module>
# ----> 1 veri[1] #seri csv dosyası olmalı.
#
# ...

# %%
veri.count() #normalde eleman sayısını verir :)
# Out:
# policyID              36634
# statecode             36634
# county                36634
# eq_site_limit         36634
# hu_site_limit         36634
# fl_site_limit         36634
# fr_site_limit         36634
# tiv_2011              36634
# tiv_2012              36634
# eq_site_deductible    36634
# hu_site_deductible    36634
# fl_site_deductible    36634
# fr_site_deductible    36634
# point_latitude        36634
# point_longitude       36634
# line                  36634
# construction          36634
# point_granularity     36634
# dtype: int64

# %%
len(veri)
# Out:
# 36634

# %%
veri.sum() #toplam verir
# Out:
# policyID                                                    20099681407
# statecode             FLFLFLFLFLFLFLFLFLFLFLFLFLFLFLFLFLFLFLFLFLFLFL...
# county                CLAY COUNTYCLAY COUNTYCLAY COUNTYCLAY COUNTYCL...
# eq_site_limit                                                2.6797e+10
# hu_site_limit                                               7.59917e+10
# fl_site_limit                                                2.4347e+10
# fr_site_limit                                               3.63106e+10
# tiv_2011                                                    7.96011e+10
# tiv_2012                                                    9.41862e+10
# eq_site_deductible                                          2.85302e+07
# hu_site_deductible                                           2.5783e+08
# fl_site_deductible                                          7.05033e+06
# fr_site_deductible                                               970200
# ...

# %%
veri.mean()
# Out:
# policyID              5.486619e+05
# eq_site_limit         7.314780e+05
# hu_site_limit         2.074348e+06
# fl_site_limit         6.646009e+05
# fr_site_limit         9.911724e+05
# tiv_2011              2.172875e+06
# tiv_2012              2.571004e+06
# eq_site_deductible    7.787908e+02
# hu_site_deductible    7.037985e+03
# fl_site_deductible    1.924532e+02
# fr_site_deductible    2.648359e+01
# point_latitude        2.808748e+01
# point_longitude      -8.190357e+01
# point_granularity     1.640907e+00
# dtype: float64

# %%
veri.std()
# Out:
# policyID              2.599129e+05
# eq_site_limit         1.752300e+07
# hu_site_limit         1.964150e+07
# fl_site_limit         1.746114e+07
# fr_site_limit         1.767178e+07
# tiv_2011              2.015015e+07
# tiv_2012              2.036777e+07
# eq_site_deductible    4.787979e+04
# hu_site_deductible    9.582593e+04
# fl_site_deductible    8.037714e+03
# fr_site_deductible    4.702741e+03
# point_latitude        1.647734e+00
# point_longitude       1.809066e+00
# point_granularity     1.070561e+00
# dtype: float64

# %%
veri.max()
# Out:
# policyID                         999971
# statecode                            FL
# county                WASHINGTON COUNTY
# eq_site_limit                  2.16e+09
# hu_site_limit                  2.16e+09
# fl_site_limit                  2.16e+09
# fr_site_limit                  2.16e+09
# tiv_2011                       2.16e+09
# tiv_2012                      1.701e+09
# eq_site_deductible          6.27376e+06
# hu_site_deductible             7.38e+06
# fl_site_deductible               450000
# fr_site_deductible               900000
# point_latitude                  30.9898
# point_longitude                -80.0333
# line                        Residential
# construction                       Wood
# point_granularity                     7
# dtype: object

# %%
veri.min()
# Out:
# policyID                      100074
# statecode                         FL
# county                ALACHUA COUNTY
# eq_site_limit                      0
# hu_site_limit                      0
# fl_site_limit                      0
# fr_site_limit                      0
# tiv_2011                          90
# tiv_2012                       73.37
# eq_site_deductible                 0
# hu_site_deductible                 0
# fl_site_deductible                 0
# fr_site_deductible                 0
# point_latitude               24.5475
# point_longitude             -87.4473
# line                      Commercial
# construction                 Masonry
# point_granularity                  1
# dtype: object

# %%
veri.median()
# Out:
# policyID              548525.000000
# eq_site_limit              0.000000
# hu_site_limit         192691.085000
# fl_site_limit              0.000000
# fr_site_limit              0.000000
# tiv_2011              202105.065000
# tiv_2012              241630.985000
# eq_site_deductible         0.000000
# hu_site_deductible         0.000000
# fl_site_deductible         0.000000
# fr_site_deductible         0.000000
# point_latitude            28.057077
# point_longitude          -81.585700
# point_granularity          1.000000
# dtype: float64

# %%
veri.describe() #genel olarak hepsini verir.
# Out:
#             policyID  eq_site_limit  hu_site_limit  fl_site_limit  \
# count   36634.000000   3.663400e+04   3.663400e+04   3.663400e+04
# mean   548661.937189   7.314780e+05   2.074348e+06   6.646009e+05
# std    259912.926494   1.752300e+07   1.964150e+07   1.746114e+07
# min    100074.000000   0.000000e+00   0.000000e+00   0.000000e+00
# 25%    323647.750000   0.000000e+00   4.248106e+04   0.000000e+00
# 50%    548525.000000   0.000000e+00   1.926911e+05   0.000000e+00
# 75%    774252.000000   0.000000e+00   9.163381e+05   0.000000e+00
# max    999971.000000   2.160000e+09   2.160000e+09   2.160000e+09
#
#        fr_site_limit      tiv_2011      tiv_2012  eq_site_deductible  \
# count   3.663400e+04  3.663400e+04  3.663400e+04        3.663400e+04
# mean    9.911724e+05  2.172875e+06  2.571004e+06        7.787908e+02
# std     1.767178e+07  2.015015e+07  2.036777e+07        4.787979e+04
# min     0.000000e+00  9.000000e+01  7.337000e+01        0.000000e+00
# ...
