# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
e = pd.read_csv("50ülke.csv")
e
# Out:
#     SIRALAMA                   ÜLKELER  MİLLİ GELİR     2023  BÜYÜME  \
# 0          1             United States     20412.87  24537.0    2.27
# 1          2                     China     14092.51  21574.0    6.86
# 2          3                     Japan      5167.05   5962.0    1.71
# 3          4                   Germany      4211.64   5272.0    2.51
# 4          5            United Kingdom      2936.29   3477.0    1.79
# 5          6                    France      2925.10   3586.0    1.85
# 6          7                     India      2848.23   4663.0    6.74
# 7          8                     Italy      2181.97   2554.0    1.47
# 8          9                    Brazil      2138.92   2717.0    0.98
# 9         10                    Canada      1798.51   2434.0    3.00
# 10        11                    Russia      1719.90   1974.0    1.55
# 11        12                     Korea      1693.25   2155.0    3.09
# 12        13                     Spain      1506.44   1875.0    3.05
# ...

# %%
sns.boxplot(x="KITA",y="KİŞİ BAŞINA",data=e)

# %%
sns.boxplot(x="KITA",y="KİŞİ BAŞINA",data=e,width=0.9)
plt.tight_layout()

# %%
sns.boxplot(x="KITA",y="BÜYÜME",data=e,palette="Set3")

# %%
ev = pd.read_csv("evli.csv")
ev
# Out:
#       isim  gelir     ay   evli
# 0      ali    100   ocak   evet
# 1    burak     80  şubat  hayır
# 2     veli    110   ocak   evet
# 3     fuat     45   mart  hayır
# 4    galip     60   mart   evet
# 5    davut     90  şubat   evet
# 6    tarık     80   ocak  hayır
# 7     emir     90  şubat   evet
# 8     umut    120   mart  hayır
# 9     ömer    130   mart   evet
# 10  ismail    100  şubat   evet
# 11   pınar    150   ocak  hayır
# 12   pelin    140   ocak  hayır
# 13    özge     40  şubat   evet
# 14    ışık     25  şubat  hayır
# 15    inci     76   mart   evet
# 16    faik    150  nisan   evet
# 17   ahmet     25  nisan   evet
# 18    elif     35  nisan  hayır
# 19    jale    200   mart  hayır
# 20   yeliz     46  ocak   hayır
# 21    tuna    120  şubat   evet
# 22   burak    140  şubat  hayır
# 23   selim    130  nisan  hayır
# 24    enes     90  nisan   evet

# %%
sns.boxplot(x="ay",y="gelir",data=ev)

# %%
sns.boxplot(x="ay",y="gelir",data=ev,hue="evli",palette="PRGn")
