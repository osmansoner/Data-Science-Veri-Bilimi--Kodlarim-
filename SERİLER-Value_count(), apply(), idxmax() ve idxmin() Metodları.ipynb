# %% [markdown]
# # SERİLER-Value_count(), apply(), idxmax() ve idxmin() Metodları

# %%
import pandas as pd

# %%
veri = pd.read_csv("FL_insurance_sample.csv",squeeze=True)

# %%
veri
# Out:
#        policyID statecode           county  eq_site_limit  hu_site_limit  \
# 0        119736        FL      CLAY COUNTY       498960.0      498960.00
# 1        448094        FL      CLAY COUNTY      1322376.3     1322376.30
# 2        206893        FL      CLAY COUNTY       190724.4      190724.40
# 3        333743        FL      CLAY COUNTY            0.0       79520.76
# 4        172534        FL      CLAY COUNTY            0.0      254281.50
# 5        785275        FL      CLAY COUNTY            0.0      515035.62
# 6        995932        FL      CLAY COUNTY            0.0    19260000.00
# 7        223488        FL      CLAY COUNTY       328500.0      328500.00
# 8        433512        FL      CLAY COUNTY       315000.0      315000.00
# 9        142071        FL      CLAY COUNTY       705600.0      705600.00
# 10       253816        FL      CLAY COUNTY       831498.3      831498.30
# 11       894922        FL      CLAY COUNTY            0.0       24059.09
# ...

# %%
veri.value_counts() #seri olmalı
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-8ff0bed2ebf4> in <module>
# ----> 1 veri.value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
veri.idxmax()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-e7671e76500c> in <module>
# ----> 1 veri.idxmax()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in idxmax(self, axis, skipna)
#    7593         """
#    7594         axis = self._get_axis_number(axis)
# -> 7595         indices = nanops.nanargmax(self.values, axis=axis, skipna=skipna)
#    7596         index = self._get_axis(axis)
#    7597         result = [index[i] if i >= 0 else np.nan for i in indices]
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      71             if any(self.check(obj) for obj in obj_iter):
#      72                 msg = 'reduction operation {name!r} not allowed for this dtype'
# ---> 73                 raise TypeError(msg.format(name=f.__name__.replace('nan', '')))
#      74             try:
# ...

# %%
    veri.idxmin()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-802ff2d00235> in <module>
# ----> 1 veri.idxmin()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in idxmin(self, axis, skipna)
#    7557         """
#    7558         axis = self._get_axis_number(axis)
# -> 7559         indices = nanops.nanargmin(self.values, axis=axis, skipna=skipna)
#    7560         index = self._get_axis(axis)
#    7561         result = [index[i] if i >= 0 else np.nan for i in indices]
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      71             if any(self.check(obj) for obj in obj_iter):
#      72                 msg = 'reduction operation {name!r} not allowed for this dtype'
# ---> 73                 raise TypeError(msg.format(name=f.__name__.replace('nan', '')))
#      74             try:
# ...

# %%
def sınıf(gel):
    if gel <= 2000000:
        return "orta"
    elif gel >2000000 and gel < 5000000:
        return "yüksek"
    else :
        return "çok yüksek"

# %% [raw]
# veri.apply(sınıf)

# %%
veri.apply(lambda veri: veri*2)
# Out:
#        policyID statecode                          county  eq_site_limit  \
# 0        239472      FLFL          CLAY COUNTYCLAY COUNTY       997920.0
# 1        896188      FLFL          CLAY COUNTYCLAY COUNTY      2644752.6
# 2        413786      FLFL          CLAY COUNTYCLAY COUNTY       381448.8
# 3        667486      FLFL          CLAY COUNTYCLAY COUNTY            0.0
# 4        345068      FLFL          CLAY COUNTYCLAY COUNTY            0.0
# 5       1570550      FLFL          CLAY COUNTYCLAY COUNTY            0.0
# 6       1991864      FLFL          CLAY COUNTYCLAY COUNTY            0.0
# 7        446976      FLFL          CLAY COUNTYCLAY COUNTY       657000.0
# 8        867024      FLFL          CLAY COUNTYCLAY COUNTY       630000.0
# 9        284142      FLFL          CLAY COUNTYCLAY COUNTY      1411200.0
# 10       507632      FLFL          CLAY COUNTYCLAY COUNTY      1662996.6
# 11      1789844      FLFL          CLAY COUNTYCLAY COUNTY            0.0
# ...
